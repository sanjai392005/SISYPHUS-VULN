# %% [markdown]
# # Test Notebook
# This is a sample notebook for testing the vulnerability scanner.

# %%
# Standard imports
import os
import sys
import json

# %%
# Data science imports
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Web and API imports (potential vulnerabilities)
import requests
import flask

# %%
# Some code that uses these packages
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
print(df.head())
